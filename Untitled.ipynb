# %% [markdown]
# # CAS Taichu Selection 2026: 引力波研究项目
#
# ## 项目简介
# [在此处简要描述项目的科学目标：例如，本项目旨在通过数值相对论模拟双黑洞碰撞过程，并研究空间引力波探测器 LISA 的响应特性。]
#
# ---
#
# ## 任务进度摘要 (Task Status)
#
# | 任务编号 | 任务名称 |成果链接 |
# | :--- | :--- | :--- | :--- |
# | **Task 06** | LISA 探测器响应灵敏度 | [理论推导与代码](./Task_06_LISA_Sensitivity/) |
# | **Task 07** | 基于Docker+GRChombo的双黑洞数值相对论模拟 | [参数与结果](./Task_09_GRChombo_Simulation/) |
# | **Task 08** | 利用个人电脑或HPC编译Chombo与GRChombo | [编译配置记录](./Task_08_Compilation/) |
# | **Task 09** | 利用个人电脑或HPC进行双黑洞模拟并提取引力波 | [数据与波形图](./Task_09_GRChombo_Simulation/) |
#
# ---
#
# ## 核心研究成果 (Key Results)
#
# ### 1. 数值仿真可视化 (Simulation Visualization)
# [描述你的仿真视频内容，例如：使用 Magma 色表展示共形因子 chi 的演化过程。]
# * **演化视频**: [点击查看视频](./Task_09_GRChombo_Simulation/figures/BBH_Evolution_Final.mp4)
#
# ### 2. 引力波形提取 (Waveform Analysis)
# [描述波形提取的模式(l=2, m=0)以及物理特征（如 Merger 和 Ringdown 阶段）。]
# * **波形图像**: ![Waveform](./Task_09_GRChombo_Simulation/figures/Weyl4_mode_20_combined.png)
#
# ---
#
# ## 环境与技术栈 (Environment & Stack)
#
# * **操作系统**: WSL2 (Ubuntu 24.04)
# * **计算框架**: GRChombo / Chombo
# * **并行计算**: OpenMPI / HDF5 (Parallel I/O)
# * **后处理工具**: Python (NumPy, Matplotlib, FFmpeg) / VisIt
#
# ---
#
# ## 目录结构说明 (Repository Structure)
#
# * **Task_06_LISA_Sensitivity/**: 包含针对 arXiv:2108.01167 的推导文档与 Python 模拟代码。
# * **Task_08_Compilation/**: 记录本地环境 OpenMPI + HDF5 编译优化参数及 `Make.defs.local`。
# * **Task_09_GRChombo_Simulation/**: 包含 BBH 模拟的所有参数文件、波形数据及分析脚本。
#     * **data/**: 原始 `.dat` 提取数据（Weyl4, Punctures）。
#     * **figures/**: 导出的科学图表（PNG）与演化视频（MP4）。
#
# ---
#
# ## 参考文献 (References)
# 1. arXiv:2108.01167 [astro-ph.IM]
# 2. GRChombo Official Documentation: https://www.grchombo.org/
#
# ---
# **Produced by [你的名字]**
# **CAS Selection 2026**
